# %% [markdown]
# <a href="https://colab.research.google.com/github/KaushalNaik02/Machine-Learning-Projects/blob/main/01_Linear_regression_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Linear Regression Project")
# Out:
# Linear Regression Project

# %%
print("This is testing cell for Second Commit")
# Out:
# This is testing cell for Second Commit
